# %%
import bibtexparser
import pandas as pd

# %%
with open("ScienceDirect_citations_1667415329979.bib") as bibtex_file:
    bib_database = bibtexparser.load(bibtex_file)

# %%
df = pd.DataFrame(bib_database.entries)

# %%
df[['author', 'title', 'journal', 'year', 'abstract', 'keywords', 'url']]
# Out:
#                                                author  \
# 0   Damir Ljuhar and Alexander T. Gibbons and Todd...
# 1   Patrina SP Poh and Thomas Lingner and Stefan K...
# 2   Soraya Dias and Pedro Espadinha-Cruz and Flori...
# 3   Tharmalingam Sivarupan and Nagasivamuni Balasu...
# 4                                                 NaN
# ..                                                ...
# 56     Ahmad Beltagui and Breno Nunes and Stefan Gold
# 57                                        Susan Bates
# 58    Rohit Pratyush Behera and Hortense {Le Ferrand}
# 59  Yasanur Kayikci and Yigit Kazancoglu and Nazli...
# 60                                   Joshua M. Pearce
#
#                                                 title  \
# 0   Emerging technology and their application to p...
# 1   Enabling technologies towards personalization ...
# 2   Understanding how Additive Manufacturing influ...
# 3   A review on the progress and challenges of bin...
# ...
